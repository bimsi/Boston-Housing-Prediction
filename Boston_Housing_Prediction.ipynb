# %% [markdown]
# <a href="https://colab.research.google.com/github/bimsi/Boston-Housing-Prediction/blob/main/Boston_Housing_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing dataset from Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
boston_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Boston Housing Prediction/Boston Dataset.csv')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Loading dataset

# %%
boston_data
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
boston_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %% [markdown]
# ### Droppiing unnamed columns

# %%
# boston_data.drop(columns=['Unnamed: 0'], axis=0, inplace=True)

# %% [markdown]
# ### Data type info

# %%
boston_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %% [markdown]
# ### Statistical info

# %%
boston_data.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# ## Pre-processing the dataset

# %% [markdown]
# ### Check for the null values

# %%
boston_data.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# ### Create box-plots

# %%
fig, ax = plt.subplots(ncols=7, nrows=2, figsize=(20, 10)) # creating figure (fig) and sub-plots (ax)
index = 0
ax = ax.flatten() # converts the 2D grid of subplots (ax) into a 1D array

for col, value in boston_data.items():
    sns.boxplot(y=col, data=boston_data, ax=ax[index]) # for each column, creates a box plot using Seaborn
    index += 1 # moves to the next subplot for the next iteration
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0) # adjusting layouts
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-6220e2bb588f> in <cell line: 5>()
#       4
#       5 for col, value in boston_data.items():
# ----> 6     sns.boxplot(y=col, data=boston_data, ax=ax[index]) # for each column, creates a box plot using Seaborn
#       7     index += 1 # moves to the next subplot for the next iteration
#       8 plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0) # adjusting layouts
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %% [markdown]
# ### Create distribution plot

# %%
fig, ax = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
ax = ax.flatten()

for col, value in boston_data.items():
    sns.distplot(value, ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
# Out:
# <ipython-input-15-33d4f2b05348>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(value, ax=ax[index])
# <ipython-input-15-33d4f2b05348>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(value, ax=ax[index])
# <ipython-input-15-33d4f2b05348>:6: UserWarning:
#
# ...

# %% [markdown]
# ## Min-Max Normalization

# %%
cols = ['crim', 'zn', 'tax', 'black']
for col in cols:
    # Find minimum and maximum of that column
    minimum = min(boston_data[col])
    maximum = max(boston_data[col])

    # Normalize the column values
    boston_data[col] = (boston_data[col] - minimum) / (maximum - minimum)

# %%
fig, ax = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
ax = ax.flatten()

for col, value in boston_data.items():
    sns.distplot(value, ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
# Out:
# <ipython-input-16-33d4f2b05348>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(value, ax=ax[index])
# <ipython-input-16-33d4f2b05348>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(value, ax=ax[index])
# <ipython-input-16-33d4f2b05348>:6: UserWarning:
#
# ...

# %% [markdown]
# ### Standardization

# %%
from sklearn import preprocessing # import the scaler
scalar = preprocessing.StandardScaler() # create a scaler object

# %% [markdown]
# ### Fit data

# %%
scaled_cols = scalar.fit_transform(boston_data[cols]) # fitting and transformating
scaled_cols = pd.DataFrame(scaled_cols, columns=cols)
scaled_cols.head() # displaying the first few rows
# Out:
#        crim        zn       tax     black
# 0 -0.419782  0.284830 -0.666608  0.441052
# 1 -0.417339 -0.487722 -0.987329  0.441052
# 2 -0.417342 -0.487722 -0.987329  0.396427
# 3 -0.416750 -0.487722 -1.106115  0.416163
# 4 -0.412482 -0.487722 -1.106115  0.441052

# %% [markdown]
# ### Integrating standardized data

# %%
for col in cols:
    boston_data[col] = scaled_cols[col]

# %%
fig, ax = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
ax = ax.flatten()

for col, value in boston_data.items():
    sns.distplot(value, ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
# Out:
# <ipython-input-21-33d4f2b05348>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(value, ax=ax[index])
# <ipython-input-21-33d4f2b05348>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(value, ax=ax[index])
# <ipython-input-21-33d4f2b05348>:6: UserWarning:
#
# ...

# %% [markdown]
# ## Co-relation Matrix

# %%
corr = boston_data.corr()
plt.figure(figsize=(20,10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### Generating regression plot

# %%
sns.regplot(y=boston_data['medv'], x=boston_data['lstat'])
# Out:
# <Axes: xlabel='lstat', ylabel='medv'>

# %%
sns.regplot(y=boston_data['medv'], x=boston_data['rm'])
# Out:
# <Axes: xlabel='rm', ylabel='medv'>

# %% [markdown]
# ## Input split

# %%
X = boston_data.drop(columns=['medv', 'rad'], axis=1)
y = boston_data['medv']

# %% [markdown]
# ## Model traininng

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error

def train(model, X, y):
    # Train the model
    x_train, x_test, y_train, y_test = train_test_split(X, y, random_state=42)
    model.fit(x_train, y_train)

    # Predict on the test set
    pred = model.predict(x_test)

    # Perform cross-validation
    cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    cv_score = np.abs(np.mean(cv_score))

    print("Model Report")
    print("MSE:", mean_squared_error(y_test, pred))
    print('CV Score:', cv_score)

# %% [markdown]
# ### Visualizing coefficients

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()  # Create a linear regression model with normalization

train(model, X, y)  # Call the previously defined train function to train the model
coef = pd.Series(model.coef_, X.columns).sort_values()  # Extract and sort coefficients
coef.plot(kind='bar', title='Model Coefficients')  # Visualize coefficients as a bar plot
# Out:
# Model Report
# MSE: 24.008125250723154
# CV Score: 36.253247271604046
# <Axes: title={'center': 'Model Coefficients'}>

# %% [markdown]
# ### Visualizing feature importance

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importance')
# Out:
# Model Report
# MSE: 19.159291338582676
# CV Score: 81.2012479130266
# <Axes: title={'center': 'Feature Importance'}>

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importance')
# Out:
# Model Report
# MSE: 10.336850141732283
# CV Score: 24.377171364472908
# <Axes: title={'center': 'Feature Importance'}>

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importance')
# Out:
# Model Report
# MSE: 10.348485519685042
# CV Score: 20.127632147019977
# <Axes: title={'center': 'Feature Importance'}>

# %%
import xgboost as xgb
model = xgb.XGBRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importance')
# Out:
# Model Report
# MSE: 6.897163917326067
# CV Score: 22.985030764762286
# <Axes: title={'center': 'Feature Importance'}>
